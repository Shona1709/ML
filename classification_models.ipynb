# %% [markdown]
# <a href="https://colab.research.google.com/github/Shona1709/ML/blob/Data-Science/classification_models.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Hello Anaconda")
# Out:
# Hello Anaconda

# %%
import graphviz

# %%
import time
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.pyplot import figure
import seaborn as sns
from sklearn import preprocessing
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report,confusion_matrix
from sklearn import tree
from sklearn.ensemble import RandomForestClassifier
from sklearn import svm

# %%
import graphviz
data = pd.read_csv('C:/breast_cancer_final.csv');
y = data['diagnosis']                   # M or B
list = ['id','diagnosis']
x = data.drop(list,axis=1)

# %%
import os
os.environ["PATH"] += os.pathsep + 'C:\Program Files (x86)\Graphviz2.38\bin\dot.exe'
import graphviz
from sklearn.tree import DecisionTreeClassifier, export_graphviz


X_Train, X_Test, Y_Train, Y_Test = train_test_split(x, y, test_size = 0.30,
                                                    random_state = 101)
trainedtree = tree.DecisionTreeClassifier().fit(X_Train, Y_Train)
data = export_graphviz(trainedtree,out_file=None,feature_names= x.columns,
                       class_names=['malignant', 'benign'],
                       filled=True, rounded=True,
                       max_depth=4,
                       special_characters=True)
graph = graphviz.Source(data)
graph

# %%
print("attempting RFE")
# Out:
# attempting RFE

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import seaborn as sns # data visualization library
import matplotlib.pyplot as plt
import time
from subprocess import check_output
import warnings
warnings.filterwarnings("ignore", category=FutureWarning)

# %%
data = pd.read_csv('C:/breast_cancer_final.csv');

# %%
y = data['diagnosis']                   # M or B
list = ['id','diagnosis']
x = data.drop(list,axis = 1 )

# %%
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import f1_score, confusion_matrix
from sklearn.metrics import accuracy_score, recall_score

#It appears that the function recall_score needs to have y in a binary format, unlike accuracy_score can
#take into account the alphabetical format too.
#We write y in the binary format, with B=0 and M=1
y = y.replace("B", 0)
y = y.replace("M", 1)

# %%
drop_list = ['perimeter_mean','smoothness_mean','compactness_mean','symmetry_mean','fractal_dimension_mean','texture_se','perimeter_se','smoothness_se','compactness_se','concavity_se','concave points_se','symmetry_se','compactness_worst','fractal_dimension_worst']
x_1 = x.drop(drop_list,axis = 1 )

# %%
x_train, x_test, y_train, y_test = train_test_split(x_1, y, test_size=0.3, random_state=42)
clf_rf = RandomForestClassifier(random_state=43)
clr_rf = clf_rf.fit(x_train,y_train)

# %%
recall = recall_score(y_test,clf_rf.predict(x_test))
print('Recall is: ', recall)
accuracy = accuracy_score(y_test,clf_rf.predict(x_test))
print('Accuracy is: ', accuracy)
f1 = f1_score(y_test,clf_rf.predict(x_test))
print('F1 score is: ', f1)
cm = confusion_matrix(y_test,clf_rf.predict(x_test))
sns.heatmap(cm,annot=True,fmt="d")
# Out:
# Recall is:  0.9365079365079365
# Accuracy is:  0.9707602339181286
# F1 score is:  0.9593495934959351

# %%
print("selecting random forest of all methods")
# Out:
# selecting random forest of all methods

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import seaborn as sns # data visualization library
import matplotlib.pyplot as plt
import time
from subprocess import check_output
import warnings
warnings.filterwarnings("ignore", category=FutureWarning)

data = pd.read_csv('C:/breast_cancer_final.csv');
y = data['diagnosis']                   # M or B
list = ['id','diagnosis']
x = data.drop(list,axis = 1 )
y = y.replace("B", 0)
y = y.replace("M", 1)
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix

from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import f1_score, confusion_matrix
from sklearn.metrics import accuracy_score, recall_score

X_train, X_test, Y_train, Y_test = train_test_split(x, y, test_size=0.3, random_state=42)

#Using Logistic Regression Algorithm to the Training Set
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

from sklearn.linear_model import LogisticRegression
clf_rf = LogisticRegression(random_state = 0)
clr_rf = clf_rf.fit(X_train,Y_train)
cm = confusion_matrix(Y_test,clf_rf.predict(X_test))
sns.heatmap(cm,annot=True,fmt="d")
accuracy = accuracy_score(Y_test,clf_rf.predict(X_test))
f1 = f1_score(Y_test,clf_rf.predict(X_test))
print('F1 score is: ', f1)
print('Accuracy is: ', accuracy)
# Out:
# F1 score is:  0.9763779527559054
# Accuracy is:  0.9824561403508771

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import seaborn as sns # data visualization library
import matplotlib.pyplot as plt
import time
from subprocess import check_output
import warnings
warnings.filterwarnings("ignore", category=FutureWarning)

data = pd.read_csv('C:/breast_cancer_final.csv');
y = data['diagnosis']                   # M or B
list = ['id','diagnosis']
x = data.drop(list,axis = 1 )

from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix

from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.naive_bayes import GaussianNB
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import f1_score, confusion_matrix
from sklearn.metrics import accuracy_score, recall_score

X_train, X_test, Y_train, Y_test = train_test_split(x, y, test_size=0.3, random_state=42)

#Using Logistic Regression Algorithm to the Training Set

from sklearn.linear_model import LogisticRegression
clf_rf = KNeighborsClassifier(n_neighbors = 5, metric = 'minkowski', p = 2)
clr_rf = clf_rf.fit(X_train,Y_train)
cm = confusion_matrix(Y_test,clf_rf.predict(X_test))
sns.heatmap(cm,annot=True,fmt="d")
accuracy = accuracy_score(Y_test,clf_rf.predict(X_test))
print('Accuracy is: ', accuracy)
# Out:
# Accuracy is:  0.9590643274853801

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import seaborn as sns # data visualization library
import matplotlib.pyplot as plt
import time
from subprocess import check_output
import warnings
warnings.filterwarnings("ignore", category=FutureWarning)

data = pd.read_csv('C:/breast_cancer_final.csv');
y = data['diagnosis']                   # M or B
list = ['id','diagnosis']
x = data.drop(list,axis = 1 )

from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix

from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.naive_bayes import GaussianNB
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import f1_score, confusion_matrix
from sklearn.metrics import accuracy_score, recall_score
y = y.replace("B", 0)
y = y.replace("M", 1)
X_train, X_test, Y_train, Y_test = train_test_split(x, y, test_size=0.3, random_state=42)

#Using Logistic Regression Algorithm to the Training Set

from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

from sklearn.linear_model import LogisticRegression
clf_rf =SVC(kernel = 'linear', random_state = 0)
clr_rf = clf_rf.fit(X_train,Y_train)
cm = confusion_matrix(Y_test,clf_rf.predict(X_test))
sns.heatmap(cm,annot=True,fmt="d")
accuracy = accuracy_score(Y_test,clf_rf.predict(X_test))
f1 = f1_score(Y_test,clf_rf.predict(X_test))
print('F1 score is: ', f1)
print('Accuracy is: ', accuracy)
# Out:
# F1 score is:  0.9682539682539683
# Accuracy is:  0.9766081871345029

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import seaborn as sns # data visualization library
import matplotlib.pyplot as plt
import time
from subprocess import check_output
import warnings
warnings.filterwarnings("ignore", category=FutureWarning)

data = pd.read_csv('C:/breast_cancer_final.csv');
y = data['diagnosis']                   # M or B
list = ['id','diagnosis']
x = data.drop(list,axis = 1 )

from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix

from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.naive_bayes import GaussianNB
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import f1_score, confusion_matrix
from sklearn.metrics import accuracy_score, recall_score

X_train, X_test, Y_train, Y_test = train_test_split(x, y, test_size=0.3, random_state=42)

#Using Logistic Regression Algorithm to the Training Set

from sklearn.linear_model import LogisticRegression
clf_rf =SVC(kernel = 'rbf', random_state = 0)
clr_rf = clf_rf.fit(X_train,Y_train)
cm = confusion_matrix(Y_test,clf_rf.predict(X_test))
sns.heatmap(cm,annot=True,fmt="d")
accuracy = accuracy_score(Y_test,clf_rf.predict(X_test))
print('Accuracy is: ', accuracy)
# Out:
# Accuracy is:  0.631578947368421

# %%
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import seaborn as sns # data visualization library
import matplotlib.pyplot as plt
import time
from subprocess import check_output
import warnings
warnings.filterwarnings("ignore", category=FutureWarning)

data = pd.read_csv('C:/breast_cancer_final.csv');
y = data['diagnosis']                   # M or B
list = ['id','diagnosis']
x = data.drop(list,axis = 1 )

from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix

from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.naive_bayes import GaussianNB
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import f1_score, confusion_matrix
from sklearn.metrics import accuracy_score, recall_score

X_train, X_test, Y_train, Y_test = train_test_split(x, y, test_size=0.3, random_state=42)

#Using Logistic Regression Algorithm to the Training Set

from sklearn.linear_model import LogisticRegression
clf_rf =GaussianNB()
clr_rf = clf_rf.fit(X_train,Y_train)
cm = confusion_matrix(Y_test,clf_rf.predict(X_test))
sns.heatmap(cm,annot=True,fmt="d")
accuracy = accuracy_score(Y_test,clf_rf.predict(X_test))
print('Accuracy is: ', accuracy)
# Out:
# Accuracy is:  0.9415204678362573

# %%
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import seaborn as sns # data visualization library
import matplotlib.pyplot as plt
import time
from subprocess import check_output
import warnings
warnings.filterwarnings("ignore", category=FutureWarning)

data = pd.read_csv('C:/breast_cancer_final.csv');
y = data['diagnosis']                   # M or B
list = ['id','diagnosis']
x = data.drop(list,axis = 1 )

from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix

from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.naive_bayes import GaussianNB
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import f1_score, confusion_matrix
from sklearn.metrics import accuracy_score, recall_score

X_train, X_test, Y_train, Y_test = train_test_split(x, y, test_size=0.3, random_state=42)

#Using Logistic Regression Algorithm to the Training Set

from sklearn.linear_model import LogisticRegression
clf_rf =DecisionTreeClassifier(criterion = 'entropy', random_state = 0)
clr_rf = clf_rf.fit(X_train,Y_train)
cm = confusion_matrix(Y_test,clf_rf.predict(X_test))
sns.heatmap(cm,annot=True,fmt="d")
accuracy = accuracy_score(Y_test,clf_rf.predict(X_test))
print('Accuracy is: ', accuracy)
# Out:
# Accuracy is:  0.9590643274853801

# %%
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import seaborn as sns # data visualization library
import matplotlib.pyplot as plt
import time
from subprocess import check_output
import warnings
warnings.filterwarnings("ignore", category=FutureWarning)

data = pd.read_csv('C:/breast_cancer_final.csv');
y = data['diagnosis']                   # M or B
list = ['id','diagnosis']
x = data.drop(list,axis = 1 )

from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix

from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.naive_bayes import GaussianNB
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import f1_score, confusion_matrix
from sklearn.metrics import accuracy_score, recall_score

y = y.replace("B", 0)
y = y.replace("M", 1)

#Feature Scaling


X_train, X_test, Y_train, Y_test = train_test_split(x, y, test_size=0.3, random_state=42)



from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)
#Using Logistic Regression Algorithm to the Training Se
from sklearn.linear_model import LogisticRegression
clf_rf =RandomForestClassifier(n_estimators = 10, criterion = 'entropy', random_state = 0)

clr_rf = clf_rf.fit(X_train,Y_train)
cm = confusion_matrix(Y_test,clf_rf.predict(X_test))
sns.heatmap(cm,annot=True,fmt="d")
accuracy = accuracy_score(Y_test,clf_rf.predict(X_test))
f1 = f1_score(Y_test,clf_rf.predict(X_test))
print('F1 score is: ', f1)
print('Accuracy is: ', accuracy)
# Out:
# F1 score is:  0.9508196721311476
# Accuracy is:  0.9649122807017544

# %%
print("attempting rfe with svc")
# Out:
# attempting rfe with svc

# %%
X_train, X_test, Y_train, Y_test = train_test_split(x, y, test_size=0.3, random_state=42)
from sklearn.feature_selection import RFE
clf_rf_2 =SVC(kernel = 'linear', random_state = 0)
rfe = RFE(estimator=clf_rf_2, n_features_to_select=16, step=1)
rfe = rfe.fit(X_train, Y_train)

# %%
print('Chosen best 16 feature by rfe:',X_train.columns[rfe.support_])
# Out:
# Chosen best 16 feature by rfe: Index(['radius_mean', 'texture_mean', 'smoothness_mean', 'compactness_mean',
#        'concavity_mean', 'concave points_mean', 'symmetry_mean', 'radius_se',
#        'texture_se', 'perimeter_se', 'texture_worst', 'smoothness_worst',
#        'compactness_worst', 'concavity_worst', 'concave points_worst',
#        'symmetry_worst'],
#       dtype='object')

# %%
drop_list = ["radius_worst","perimeter_mean","perimeter_worst","area_mean","area_worst","smoothness_se","area_se","compactness_se","concavity_se","concave points_se","symmetry_se","fractal_dimension_mean","fractal_dimension_se","fractal_dimension_worst"]
print("Number of eliminated features :", len(drop_list))
x_2 = x.drop(drop_list,axis = 1)
# Out:
# Number of eliminated features : 14

# %%
X_train, X_test, Y_train, Y_test = train_test_split(x_2, y, test_size=0.3, random_state=42)

#Using Logistic Regression Algorithm to the Training Set

from sklearn.linear_model import LogisticRegression
clf_rf =SVC(kernel = 'linear', random_state = 0)
clr_rf = clf_rf.fit(X_train,Y_train)
cm = confusion_matrix(Y_test,clf_rf.predict(X_test))
sns.heatmap(cm,annot=True,fmt="d")
accuracy = accuracy_score(Y_test,clf_rf.predict(X_test))
print('Accuracy is: ', accuracy)
# Out:
# Accuracy is:  0.9649122807017544

# %%
print("attempting RFE with Random forest")
# Out:
# attempting RFE with Random forest

# %%
X_train, X_test, Y_train, Y_test = train_test_split(x, y, test_size=0.3, random_state=42)
from sklearn.feature_selection import RFE
clf_rf_2 = RandomForestClassifier(random_state=43)
rfe = RFE(estimator=clf_rf_2, n_features_to_select=16, step=1)
rfe = rfe.fit(X_train, Y_train)
print('Chosen best 16 feature by rfe:',X_train.columns[rfe.support_])
# Out:
# Chosen best 16 feature by rfe: Index(['radius_mean', 'texture_mean', 'perimeter_mean', 'concavity_mean',
#        'concave points_mean', 'radius_se', 'area_se', 'fractal_dimension_se',
#        'radius_worst', 'texture_worst', 'perimeter_worst', 'area_worst',
#        'smoothness_worst', 'concavity_worst', 'concave points_worst',
#        'symmetry_worst'],
#       dtype='object')

# %%
drop_list = ["texture_se","perimeter_se","area_mean","smoothness_se","smoothness_mean","compactness_se","compactness_mean","compactness_worst","concavity_se","concave points_se","symmetry_se","symmetry_mean","fractal_dimension_mean","fractal_dimension_worst"]
print("Number of eliminated features :", len(drop_list))
x_2 = x.drop(drop_list,axis = 1)
# Out:
# Number of eliminated features : 14

# %%
X_train, X_test, Y_train, Y_test = train_test_split(x_2, y, test_size=0.3, random_state=42)

#Using Logistic Regression Algorithm to the Training Set

from sklearn.linear_model import LogisticRegression
clf_rf =SVC(kernel = 'linear', random_state = 0)
clr_rf = clf_rf.fit(X_train,Y_train)
cm = confusion_matrix(Y_test,clf_rf.predict(X_test))
sns.heatmap(cm,annot=True,fmt="d")
accuracy = accuracy_score(Y_test,clf_rf.predict(X_test))
print('Accuracy is: ', accuracy)
# Out:
# Accuracy is:  0.9766081871345029

# %%
y = y.replace("B", 0)
y = y.replace("M", 1)

X_train, X_test, Y_train, Y_test = train_test_split(x_2, y, test_size=0.3, random_state=42)

#Using Logistic Regression Algorithm to the Training Set

from sklearn.linear_model import LogisticRegression
clf_rf =RandomForestClassifier(random_state=43)
clr_rf = clf_rf.fit(X_train,Y_train)
cm = confusion_matrix(Y_test,clf_rf.predict(X_test))
sns.heatmap(cm,annot=True,fmt="d")
accuracy = accuracy_score(Y_test,clf_rf.predict(X_test))
print('Accuracy is: ', accuracy)
# Out:
# Accuracy is:  0.9707602339181286

# %%
X_train.shape
# Out:
# (398, 16)

# %%
Y_test.head
# Out:
# <bound method NDFrame.head of 204    0
# 70     1
# 131    1
# 431    0
# 540    0
# 567    1
# 369    1
# 29     1
# 81     0
# 477    0
# 457    0
# 167    1
# 165    0
# 329    1
# 527    0
# 83     1
# 511    0
# 556    0
# 101    0
# 535    1
# 73     1
# 394    0
# 393    1
# 425    0
# 305    0
# 76     0
# 384    0
# 555    0
# 362    0
# 72     1
#       ..
# 18     1
# 390    0
# 287    0
# 512    1
# 402    0
# 446    1
# 210    1
# 184    1
# 442    0
# 54     1
# 404    0
# 46     0
# 93     0
# 231    0
# 108    1
# 244    1
# 568    0
# 434    0
# 428    0
# 192    0
# 341    0
# 185    0
# 355    0
# 414    1
# 426    0
# 69     0
# 542    0
# 176    0
# 501    1
# 247    0
# Name: diagnosis, Length: 171, dtype: int64>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

Y_test['diagnosis'].value_counts().plot(kind='bar')
print(Y_test['diagnosis'].value_counts())
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.Int64HashTable.get_item()
#
# TypeError: an integer is required
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-85-fe7076e8d1b4> in <module>()
#       4 import seaborn as sns
#       5
# ----> 6 Y_test['diagnosis'].value_counts().plot(kind='bar')
#       7 print(Y_test['diagnosis'].value_counts())
#       8 plt.show()
#
# C:\Anaconda3\lib\site-packages\pandas\core\series.py in __getitem__(self, key)
#     621         key = com._apply_if_callable(key, self)
#     622         try:
# --> 623             result = self.index.get_value(self, key)
#     624
# ...

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
data = pd.read_csv('C:/breast_cancer_final.csv');
y = data['diagnosis']
X_train, X_test, Y_train, Y_test = train_test_split(x_2, y, test_size=0.3, random_state=42)

# %%
Y_test['diagnosis'].value_counts().plot(kind='bar')
print(Y_test['diagnosis'].value_counts())
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.Int64HashTable.get_item()
#
# TypeError: an integer is required
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-87-c18dc82e96ba> in <module>()
# ----> 1 Y_test['diagnosis'].value_counts().plot(kind='bar')
#       2 print(Y_test['diagnosis'].value_counts())
#       3 plt.show()
#
# C:\Anaconda3\lib\site-packages\pandas\core\series.py in __getitem__(self, key)
#     621         key = com._apply_if_callable(key, self)
#     622         try:
# --> 623             result = self.index.get_value(self, key)
#     624
#     625             if not is_scalar(result):
#
# ...

# %%
print("getting features with RFE+SVM")
# Out:
# getting features with RFE+SVM

# %%
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import seaborn as sns # data visualization library
import matplotlib.pyplot as plt
import time
from subprocess import check_output
import warnings
warnings.filterwarnings("ignore", category=FutureWarning)

data = pd.read_csv('C:/breast_cancer_final.csv');
y = data['diagnosis']                   # M or B
list = ['id','diagnosis']
x = data.drop(list,axis = 1 )

from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix

from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.naive_bayes import GaussianNB
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import f1_score, confusion_matrix
from sklearn.metrics import accuracy_score, recall_score

y = y.replace("B", 0)
y = y.replace("M", 1)

#Feature Scaling


X_train, X_test, Y_train, Y_test = train_test_split(x, y, test_size=0.3, random_state=42)
from sklearn.feature_selection import RFE
clf_rf_2 =SVC(kernel = 'linear', random_state = 0)
rfe = RFE(estimator=clf_rf_2, n_features_to_select=16, step=1)
rfe = rfe.fit(X_train, Y_train)


print('Chosen best 16 feature by rfe:',X_train.columns[rfe.support_])
# Out:
# Chosen best 16 feature by rfe: Index(['radius_mean', 'texture_mean', 'smoothness_mean', 'compactness_mean',
#        'concavity_mean', 'concave points_mean', 'symmetry_mean', 'radius_se',
#        'texture_se', 'perimeter_se', 'texture_worst', 'smoothness_worst',
#        'compactness_worst', 'concavity_worst', 'concave points_worst',
#        'symmetry_worst'],
#       dtype='object')

# %%
drop_list = ["area_mean","area_worst","smoothness_se","area_se","perimeter_mean","compactness_se","compactness_mean","concavity_se","concave points_se","symmetry_se","symmetry_mean","fractal_dimension_mean","area_worst","perimeter_worst","fractal_dimension_worst","radius_worst"]
print("Number of eliminated features :", len(drop_list))
x_2 = x.drop(drop_list,axis = 1)
# Out:
# Number of eliminated features : 16

# %%
X_train, X_test, Y_train, Y_test = train_test_split(x_2, y, test_size=0.3, random_state=42)

#Using Logistic Regression Algorithm to the Training Set

from sklearn.linear_model import LogisticRegression
clf_rf =SVC(kernel = 'linear', random_state = 0)
clr_rf = clf_rf.fit(X_train,Y_train)
cm = confusion_matrix(Y_test,clf_rf.predict(X_test))
sns.heatmap(cm,annot=True,fmt="d")
accuracy = accuracy_score(Y_test,clf_rf.predict(X_test))
print('Accuracy is: ', accuracy)
# Out:
# Accuracy is:  0.9649122807017544
